# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# Baze podataka sa 12 stanica u Pekingu:

filenames =["PRSA_Data_Aotizhongxin_20130301-20170228.csv","PRSA_Data_Changping_20130301-20170228.csv","PRSA_Data_Dingling_20130301-20170228.csv",
            "PRSA_Data_Dongsi_20130301-20170228.csv","PRSA_Data_Guanyuan_20130301-20170228.csv",
            "PRSA_Data_Gucheng_20130301-20170228.csv","PRSA_Data_Huairou_20130301-20170228.csv","PRSA_Data_Nongzhanguan_20130301-20170228.csv",
            "PRSA_Data_Shunyi_20130301-20170228.csv","PRSA_Data_Tiantan_20130301-20170228.csv","PRSA_Data_Wanliu_20130301-20170228.csv","PRSA_Data_Wanshouxigong_20130301-20170228.csv"]
dataframes=[]
for f in filenames:
    dataframes.append(pd.read_csv("data/"+f,index_col=0))
df_Dingling = dataframes[2].copy()
df_Huairou = dataframes[6].copy()
df_Aotizhongxin = dataframes[0].copy()
df_Changping = dataframes[1].copy()
df_Dongsi = dataframes[3].copy()
df_Guanyuan = dataframes[4].copy()
df_Nongzhanguan =dataframes[7].copy()
df_Shunyi=dataframes[8].copy()
df_Tiantan=dataframes[9].copy()
df_Wanliu=dataframes[10].copy()
df_Wanshouxigong =dataframes[11].copy()
df_Gucheng =dataframes[5].copy()

# %%
dataframes[0].head()
# Out:
#     year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# No
# 1   2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 2   2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 3   2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 4   2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 5   2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#       PRES  DEWP  RAIN   wd  WSPM       station
# No
# 1   1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 2   1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 3   1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 4   1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 5   1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
# Datum:

datetime_col = pd.date_range(start='2013-03-01 00:00:00', end='2017-02-28 23:00:00',freq='H')
for i in dataframes:
  i.set_index(datetime_col, drop = True, inplace = True)

# %%
# Ucitavanje longitude i latitude stanica:

import pandas as pd

data = {'Latitude': [39.982,40.21612,40.292,39.929,39.929,39.914,40.328,39.937,40.127,39.886,39.987,	39.878],
        'Longitude': [116.397,116.23471,116.22,116.417,116.339,116.184,116.628,116.461,116.655,116.407,116.287,116.352]
        }

df_locations = pd.DataFrame(data, columns = ['Latitude','Longitude'], index=['Aotizhongxin','Changping','Dingling','Dongsi','Guanyuan','Gucheng','Huairou','Nongzhanguan','Shunyi','Tiantan','Wanliu','Wanshouxigong'])

df_locations
# Out:
#                Latitude  Longitude
# Aotizhongxin   39.98200  116.39700
# Changping      40.21612  116.23471
# Dingling       40.29200  116.22000
# Dongsi         39.92900  116.41700
# Guanyuan       39.92900  116.33900
# Gucheng        39.91400  116.18400
# Huairou        40.32800  116.62800
# Nongzhanguan   39.93700  116.46100
# Shunyi         40.12700  116.65500
# Tiantan        39.88600  116.40700
# Wanliu         39.98700  116.28700
# Wanshouxigong  39.87800  116.35200

# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Stanice:
stations=[]
for data in dataframes:
    stations.append(data['station'].iloc[0])
print(np.array(stations))
# Out:
# ['Aotizhongxin' 'Changping' 'Dingling' 'Dongsi' 'Guanyuan' 'Gucheng'
#  'Huairou' 'Nongzhanguan' 'Shunyi' 'Tiantan' 'Wanliu' 'Wanshouxigong']

# %%
# Racunanje distanici:

import geopy.distance
distance = np.zeros((12,12))
for i in range(12):
  coords_1 = (df_locations['Latitude'][i],df_locations['Longitude'][i])
  for j in range(12):
    coords_2 = (df_locations['Latitude'][j],df_locations['Longitude'][j])
    distance[i,j]=geopy.distance.distance(coords_1, coords_2).km

# %%
# Sortiranje distanci:

import copy
distance_stations = np.zeros((12,12),dtype='int')
distance_sort = copy.deepcopy(distance) 
distance_sort.sort()
pd.DataFrame(distance_sort)
# Out:
#      0          1          2          3          4          5          6   \
# 0   0.0   6.127919   7.407362   7.693715   9.411835  10.693420  12.171300
# 1   0.0   8.518113  25.828445  29.449776  33.098644  33.823969  35.470780
# 2   0.0   8.518113  34.344323  34.912208  37.581678  41.316795  41.563575
# 3   0.0   3.864471   4.850381   6.127919   6.667614   7.934842  12.839810
# 4   0.0   5.770761   6.667614   7.523609   7.693715   7.824010  10.465987
# 5   0.0  11.965456  13.355445  14.913555  19.322322  19.706450  19.989034
# 6   0.0  22.436828  34.912208  35.683234  43.166777  45.689053  47.725229
# 7   0.0   3.864471   7.306478   7.407362  10.465987  11.392369  15.869527
# 8   0.0  22.436828  26.819011  27.273331  29.934161  34.124343  34.798014
# 9   0.0   4.787854   4.850381   7.306478   7.523609  10.693420  15.197467
# 10  0.0   7.824010   9.411835  11.965456  12.839810  13.317039  15.197467
# 11  0.0   4.787854   5.770761   7.934842  11.392369  12.171300  13.317039
#
# ...

# %%
# Matrica distance_stations cuva informaciju o rednom br(indeks u matrici stations) najblize stanice-od najblize ka najdaljoj

for i in range(0,12):
  for j in range(0,12):
    distance_stations[i,j] = int(distance[i].tolist().index(distance1[i,j]))
distance_stations
# Out:
# array([[ 0,  3,  7,  4, 10,  9, 11,  5,  8,  1,  2,  6],
#        [ 1,  2, 10,  0,  4,  5,  3,  6,  7,  8, 11,  9],
#        [ 2,  1, 10,  6,  0,  8,  4,  5,  3,  7, 11,  9],
#        [ 3,  7,  9,  0,  4, 11, 10,  5,  8,  1,  2,  6],
#        [ 4, 11,  3,  9,  0, 10,  7,  5,  1,  8,  2,  6],
#        [ 5, 10,  4, 11,  9,  0,  3,  7,  1,  2,  8,  6],
#        [ 6,  8,  2,  1,  0,  7, 10,  3,  4,  9, 11,  5],
#        [ 7,  3,  9,  0,  4, 11, 10,  5,  8,  1,  2,  6],
#        [ 8,  6,  7,  0,  3,  9,  4, 10,  1, 11,  2,  5],
#        [ 9, 11,  3,  7,  4,  0, 10,  5,  8,  1,  2,  6],
#        [10,  4,  0,  5,  3, 11,  9,  7,  1,  2,  8,  6],
#        [11,  9,  4,  3,  7,  0, 10,  5,  8,  1,  2,  6]])

# %%
# Primer - Najblize stanice za Aotizhongxin:

nearest = distance_stations[stations.index('Aotizhongxin')]
nearest[1:]
print(np.array([stations[x] for x in nearest[1:]]))
# Out:
# ['Dongsi' 'Nongzhanguan' 'Guanyuan' 'Wanliu' 'Tiantan' 'Wanshouxigong'
#  'Gucheng' 'Shunyi' 'Changping' 'Dingling' 'Huairou']

# %%
# Nedostajuce vrednosti:

for data in dataframes:
    print("{}:{}".format(data['station'].iloc[0],np.sum(np.sum(data.isna()))))
# Out:
# Aotizhongxin:7271
# Changping:5166
# Dingling:7015
# Dongsi:7600
# Guanyuan:5279
# Gucheng:4728
# Huairou:7485
# Nongzhanguan:4090
# Shunyi:8523
# Tiantan:5277
# Wanliu:6447
# Wanshouxigong:5146

# %%
# Nedostajucu vrednost cemo dopuniti sa vrednoscu najblize susedne stanice ukoliko postoji!

for data in dataframes:
    columns=data.columns
    for column in columns:
        indexes=np.where(data[column].isnull() == True)[0]
        if(len(indexes>0)):
            for index in indexes:
                nearest_station = distance_stations[stations.index(data['station'].iloc[0])][1]
                data[column].iloc[index]=dataframes[nearest_station][column].iloc[index]

# Napomena: Izbacuje upozorenje ali radi, proverila sam!
# Out:
# C:\Users\kristina\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\kristina\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\kristina\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Nedostajuce vrednosti nakon dopune najblizim susednom:

for data in dataframes:
    print("{}:{}".format(data['station'].iloc[0],np.sum(np.sum(data.isna()))))
# Out:
# Aotizhongxin:1733
# Changping:1485
# Dingling:1485
# Dongsi:1476
# Guanyuan:1240
# Gucheng:1672
# Huairou:1449
# Nongzhanguan:1476
# Shunyi:1449
# Tiantan:1608
# Wanliu:1076
# Wanshouxigong:1608

# %%
# Preostale nedostajuce brojne vrednosti dopunimo interpolacijom:

for i,data in enumerate(dataframes):
    dataframes[i]=dataframes[i].interpolate()

# %%
# Nedostajuce vrednosti nakon dopune interpolacijom:

for data in dataframes:
    print("{}:{}".format(data['station'].iloc[0],np.sum(np.sum(data.isna()))))
# Out:
# Aotizhongxin:78
# Changping:140
# Dingling:140
# Dongsi:78
# Guanyuan:78
# Gucheng:15
# Huairou:42
# Nongzhanguan:78
# Shunyi:42
# Tiantan:77
# Wanliu:61
# Wanshouxigong:77

# %%
# Preostale nedostajuce vrednosti su kategoricke i pripadaju koloni vetar!

for data in dataframes:
    na_columns=np.sum(data.isna())[np.sum(data.isna())!=0].index
    print("{}:{}".format(data['station'].iloc[0],na_columns))
# Out:
# Aotizhongxin:Index(['wd'], dtype='object')
# Changping:Index(['wd'], dtype='object')
# Dingling:Index(['wd'], dtype='object')
# Dongsi:Index(['wd'], dtype='object')
# Guanyuan:Index(['wd'], dtype='object')
# Gucheng:Index(['wd'], dtype='object')
# Huairou:Index(['wd'], dtype='object')
# Nongzhanguan:Index(['wd'], dtype='object')
# Shunyi:Index(['wd'], dtype='object')
# Tiantan:Index(['wd'], dtype='object')
# Wanliu:Index(['wd'], dtype='object')
# Wanshouxigong:Index(['wd'], dtype='object')

# %%
dataframes[0]['wd'].unique()
# Out:
# array(['NNW', 'N', 'NW', 'NNE', 'ENE', 'E', 'NE', 'W', 'SSW', 'WSW', 'SE',
#        'WNW', 'SSE', 'ESE', 'S', 'SW', nan], dtype=object)

# %%
# Dodacemo jos jednu klasu koloni vetar - UNKNOWN

for data in dataframes:
    indexes=np.where(data['wd'].isnull() == True)[0]
    for index in indexes:
          data['wd'].iloc[index]='UNKNOWN'
            
# Napomena: Izbacuje upozorenje ali radi, proverila sam!
# Out:
# C:\Users\kristina\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\kristina\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\kristina\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Vise nemamo kolonu nan - sada imamo UNKNOWN!

dataframes[0]['wd'].unique()
# Out:
# array(['NNW', 'N', 'NW', 'NNE', 'ENE', 'E', 'NE', 'W', 'SSW', 'WSW', 'SE',
#        'WNW', 'SSE', 'ESE', 'S', 'SW', 'UNKNOWN'], dtype=object)

# %%
# Nedostajuce vrednosti:

for data in dataframes:
    print("{}:{}".format(data['station'].iloc[0],np.sum(np.sum(data.isna()))))
# Out:
# Aotizhongxin:0
# Changping:0
# Dingling:0
# Dongsi:0
# Guanyuan:0
# Gucheng:0
# Huairou:0
# Nongzhanguan:0
# Shunyi:0
# Tiantan:0
# Wanliu:0
# Wanshouxigong:0

# %%
# Sezona lozenja:

for i in dataframes:
  i['heating']=i['month']
  i['heating']=i['heating'].replace([10,11,12,1,2,3],0)
  i['heating']=i['heating'].replace([4,5,6,7,8,9],1)

# %%
for i in dataframes:
  i['wd']=i['wd'].replace(['NNW','NW','N','ENE','NE','NNE','WNW'],0)
  i['wd']=i['wd'].replace(['SW','SSW','S','WSW','ESE','SE','SSE'],1)
  i['wd']=i['wd'].replace('W',2)
  i['wd']=i['wd'].replace('E',3)
  i['wd']=i['wd'].replace('UNKNOWN',4)

# %%
# Sacuvajmo baze bez nedostajucih vrednosti:
for data in dataframes:
    data.to_csv("data_without_na/" +"PRSA_Data_{}_20130301-20170228.csv".format(data['station'].iloc[0]))
